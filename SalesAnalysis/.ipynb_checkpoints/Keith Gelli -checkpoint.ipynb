# %%
import pandas as pd
import os 
import glob

# %%
df= pd.DataFrame()
filepath= "./Sales_Data/"
files= glob.glob(filepath+'/*.csv')
for file in files:
    tempfile= pd.read_csv(file)
    df = df.append(tempfile,ignore_index=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7880\5020927.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tempfile,ignore_index=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_7880\5020927.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tempfile,ignore_index=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_7880\5020927.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tempfile,ignore_index=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_7880\5020927.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tempfile,ignore_index=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_7880\5020927.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tempfile,ignore_index=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_7880\5020927.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tempfile,ignore_index=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_7880\5020927.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tempfile,ignore_index=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_7880\5020927.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tempfile,ignore_index=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_7880\5020927.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tempfile,ignore_index=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_7880\5020927.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tempfile,ignore_index=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_7880\5020927.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tempfile,ignore_index=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_7880\5020927.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tempfile,ignore_index=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186850 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 8.6+ MB

# %%
f= df['Order ID'].str.contains("NAN",na=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186305 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 9.9+ MB

# %%
# Removing the NAN 
df=df.dropna()

# %%
df[f]
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7880\2651581953.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[f]
# Empty DataFrame
# Columns: [Order ID, Product, Quantity Ordered, Price Each, Order Date, Purchase Address]
# Index: []

# %%
for x in df.index:
    if df.loc[x,'Order ID'] == 'Order ID':
        df.drop(x,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  object
#  3   Price Each        185950 non-null  object
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
# dtypes: object(6)
# memory usage: 14.0+ MB

# %%
df['Month']=df['Order Date'].str[0:2]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 186849
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  object
#  3   Price Each        185950 non-null  object
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   Month             185950 non-null  object
# dtypes: object(7)
# memory usage: 15.4+ MB

# %%
df['Quantity Ordered']=df['Quantity Ordered'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 186849
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  float32
#  3   Price Each        185950 non-null  object
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   Month             185950 non-null  object
# dtypes: float32(1), object(6)
# memory usage: 14.7+ MB

# %%
df['Price Each']=df['Price Each'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 186849
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  float32
#  3   Price Each        185950 non-null  float32
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   Month             185950 non-null  object
# dtypes: float32(2), object(5)
# memory usage: 14.0+ MB

# %%
df['Sale_value']= df['Quantity Ordered']*df['Price Each']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 186849
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  float32
#  3   Price Each        185950 non-null  float32
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   Month             185950 non-null  object
#  7   Sale_value        185950 non-null  float32
# dtypes: float32(3), object(5)
# memory usage: 14.7+ MB

# %%
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable               2.0   11.950000
# 2        176559  Bose SoundSport Headphones               1.0   99.989998
# 3        176560                Google Phone               1.0  600.000000
# 4        176560            Wired Headphones               1.0   11.990000
# 5        176561            Wired Headphones               1.0   11.990000
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)               3.0    2.990000
# 186846   259354                      iPhone               1.0  700.000000
# 186847   259355                      iPhone               1.0  700.000000
# 186848   259356      34in Ultrawide Monitor               1.0  379.989990
# 186849   259357        USB-C Charging Cable               1.0   11.950000
#
#             Order Date                         Purchase Address Month  \
# 0       04/19/19 08:46             917 1st St, Dallas, TX 75001    04
# 2       04/07/19 22:30        682 Chestnut St, Boston, MA 02215    04
# 3       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001    04
# 4       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001    04
# 5       04/30/19 09:27        333 8th St, Los Angeles, CA 90001    04
# ...                ...                                      ...   ...
# 186845  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001    09
# 186846  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016    09
# 186847  09/23/19 07:39     220 12th St, San Francisco, CA 94016    09
# 186848  09/19/19 17:30   511 Forest St, San Francisco, CA 94016    09
# 186849  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016    09
#
#         Sale_value
# 0        23.900000
# 2        99.989998
# 3       600.000000
# 4        11.990000
# 5        11.990000
# ...            ...
# 186845    8.970000
# 186846  700.000000
# 186847  700.000000
# 186848  379.989990
# 186849   11.950000
#
# [185950 rows x 8 columns]

# %%
# Out:
#        Order ID                 Product  Quantity Ordered  Price Each  \
# 186845   259353  AAA Batteries (4-pack)               3.0     2.99000
# 186846   259354                  iPhone               1.0   700.00000
# 186847   259355                  iPhone               1.0   700.00000
# 186848   259356  34in Ultrawide Monitor               1.0   379.98999
# 186849   259357    USB-C Charging Cable               1.0    11.95000
#
#             Order Date                         Purchase Address Month  \
# 186845  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001    09
# 186846  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016    09
# 186847  09/23/19 07:39     220 12th St, San Francisco, CA 94016    09
# 186848  09/19/19 17:30   511 Forest St, San Francisco, CA 94016    09
# 186849  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016    09
#
#         Sale_value
# 186845     8.97000
# 186846   700.00000
# 186847   700.00000
# 186848   379.98999
# 186849    11.95000

# %%
f2= df['Month'].str.contains('04',na=True)

# %%
df[f2]
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable               2.0   11.950000
# 2        176559  Bose SoundSport Headphones               1.0   99.989998
# 3        176560                Google Phone               1.0  600.000000
# 4        176560            Wired Headphones               1.0   11.990000
# 5        176561            Wired Headphones               1.0   11.990000
# ...         ...                         ...               ...         ...
# 112782   169191            27in FHD Monitor               1.0  149.990005
# 118424   174575       AA Batteries (4-pack)               1.0    3.840000
# 118825   174959  Bose SoundSport Headphones               1.0   99.989998
# 119667   175769  Bose SoundSport Headphones               1.0   99.989998
# 119858   175951                    LG Dryer               1.0  600.000000
#
#             Order Date                         Purchase Address Month  \
# 0       04/19/19 08:46             917 1st St, Dallas, TX 75001    04
# 2       04/07/19 22:30        682 Chestnut St, Boston, MA 02215    04
# 3       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001    04
# 4       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001    04
# 5       04/30/19 09:27        333 8th St, Los Angeles, CA 90001    04
# ...                ...                                      ...   ...
# 112782  04/01/19 00:42     310 Cherry St, Los Angeles, CA 90001    04
# 118424  04/01/19 03:21           969 Adams St, Boston, MA 02215    04
# 118825  04/01/19 00:52  288 Lincoln St, New York City, NY 10001    04
# 119667  04/01/19 02:22     974 13th St, New York City, NY 10001    04
# 119858  04/01/19 00:04          469 Walnut St, Dallas, TX 75001    04
#
#         Sale_value
# 0        23.900000
# 2        99.989998
# 3       600.000000
# 4        11.990000
# 5        11.990000
# ...            ...
# 112782  149.990005
# 118424    3.840000
# 118825   99.989998
# 119667   99.989998
# 119858  600.000000
#
# [18279 rows x 8 columns]

# %%
result=df.groupby('Month').sum()['Sale_value']
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7880\1398473406.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   result=df.groupby('Month').sum()['Sale_value']

# %%
import matplotlib.pyplot as plt

# %%
months=range(1,13)
plt.bar(months,result)
plt.xticks(months)
plt.ylabel('Sales in US Dollar ($)')
plt.xlabel('Month Number')
plt.show()

# %% [markdown]
# # Which city has more number of sales

# %%
df['City']=df['Purchase Address'].str.split(',').str[1]

# %%
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable               2.0   11.950000
# 2        176559  Bose SoundSport Headphones               1.0   99.989998
# 3        176560                Google Phone               1.0  600.000000
# 4        176560            Wired Headphones               1.0   11.990000
# 5        176561            Wired Headphones               1.0   11.990000
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)               3.0    2.990000
# 186846   259354                      iPhone               1.0  700.000000
# 186847   259355                      iPhone               1.0  700.000000
# 186848   259356      34in Ultrawide Monitor               1.0  379.989990
# 186849   259357        USB-C Charging Cable               1.0   11.950000
#
#             Order Date                         Purchase Address Month  \
# 0       04/19/19 08:46             917 1st St, Dallas, TX 75001    04
# 2       04/07/19 22:30        682 Chestnut St, Boston, MA 02215    04
# 3       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001    04
# 4       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001    04
# 5       04/30/19 09:27        333 8th St, Los Angeles, CA 90001    04
# ...                ...                                      ...   ...
# 186845  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001    09
# 186846  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016    09
# 186847  09/23/19 07:39     220 12th St, San Francisco, CA 94016    09
# 186848  09/19/19 17:30   511 Forest St, San Francisco, CA 94016    09
# 186849  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016    09
#
#         Sale_value            City
# 0        23.900000          Dallas
# 2        99.989998          Boston
# 3       600.000000     Los Angeles
# 4        11.990000     Los Angeles
# 5        11.990000     Los Angeles
# ...            ...             ...
# 186845    8.970000     Los Angeles
# 186846  700.000000   San Francisco
# 186847  700.000000   San Francisco
# 186848  379.989990   San Francisco
# 186849   11.950000   San Francisco
#
# [185950 rows x 9 columns]

# %%
res= pd.DataFrame()
res= df.groupby('City').sum()
res.info
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7880\4008050750.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   res= df.groupby('City').sum()
# <bound method DataFrame.info of                 Quantity Ordered   Price Each  Sale_value
# City
#  Atlanta                 16602.0  2779908.250  2795498.50
#  Austin                  11153.0  1809873.625  1819581.75
#  Boston                  22528.0  3637409.750  3661642.00
#  Dallas                  16730.0  2752627.750  2767975.50
#  Los Angeles             33289.0  5421435.000  5452571.00
#  New York City           27932.0  4635371.000  4664317.50
#  Portland                14053.0  2307747.500  2320490.50
#  San Francisco           50239.0  8211461.500  8262204.00
#  Seattle                 16553.0  2733296.000  2747755.50>

# %%
#cities=df['City'].unique()
cities= [city for city, df1 in df.groupby('City')]
plt.bar(cities,res['Sale_value'])

plt.xlabel('City Name')
plt.ylabel('Sale Value')

plt.xticks(rotation='vertical',size=10)

plt.show()

# %%
###### Which State has the highest Sales

# %%
df['State & Pin']= df['Purchase Address'].str.split(',').str[2]

# %%
df['State']= df['State & Pin'].str.split(' ').str[1]
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable               2.0   11.950000
# 2        176559  Bose SoundSport Headphones               1.0   99.989998
# 3        176560                Google Phone               1.0  600.000000
# 4        176560            Wired Headphones               1.0   11.990000
# 5        176561            Wired Headphones               1.0   11.990000
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)               3.0    2.990000
# 186846   259354                      iPhone               1.0  700.000000
# 186847   259355                      iPhone               1.0  700.000000
# 186848   259356      34in Ultrawide Monitor               1.0  379.989990
# 186849   259357        USB-C Charging Cable               1.0   11.950000
#
#             Order Date                         Purchase Address Month  \
# 0       04/19/19 08:46             917 1st St, Dallas, TX 75001    04
# 2       04/07/19 22:30        682 Chestnut St, Boston, MA 02215    04
# 3       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001    04
# 4       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001    04
# 5       04/30/19 09:27        333 8th St, Los Angeles, CA 90001    04
# ...                ...                                      ...   ...
# 186845  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001    09
# 186846  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016    09
# 186847  09/23/19 07:39     220 12th St, San Francisco, CA 94016    09
# 186848  09/19/19 17:30   511 Forest St, San Francisco, CA 94016    09
# 186849  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016    09
#
#         Sale_value            City State State & Pin
# 0        23.900000          Dallas    TX    TX 75001
# 2        99.989998          Boston    MA    MA 02215
# 3       600.000000     Los Angeles    CA    CA 90001
# 4        11.990000     Los Angeles    CA    CA 90001
# 5        11.990000     Los Angeles    CA    CA 90001
# ...            ...             ...   ...         ...
# 186845    8.970000     Los Angeles    CA    CA 90001
# 186846  700.000000   San Francisco    CA    CA 94016
# 186847  700.000000   San Francisco    CA    CA 94016
# 186848  379.989990   San Francisco    CA    CA 94016
# 186849   11.950000   San Francisco    CA    CA 94016
#
# [185950 rows x 11 columns]

# %%
df['Zip Code']= df['State & Pin'].str.split(' ').str[2]
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'State & Pin'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 df['Zip Code']= df['State & Pin'].str.split(' ').str[2]
#       2 df
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'State & Pin'

# %%
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable               2.0   11.950000
# 2        176559  Bose SoundSport Headphones               1.0   99.989998
# 3        176560                Google Phone               1.0  600.000000
# 4        176560            Wired Headphones               1.0   11.990000
# 5        176561            Wired Headphones               1.0   11.990000
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)               3.0    2.990000
# 186846   259354                      iPhone               1.0  700.000000
# 186847   259355                      iPhone               1.0  700.000000
# 186848   259356      34in Ultrawide Monitor               1.0  379.989990
# 186849   259357        USB-C Charging Cable               1.0   11.950000
#
#             Order Date                         Purchase Address Month  \
# 0       04/19/19 08:46             917 1st St, Dallas, TX 75001    04
# 2       04/07/19 22:30        682 Chestnut St, Boston, MA 02215    04
# 3       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001    04
# 4       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001    04
# 5       04/30/19 09:27        333 8th St, Los Angeles, CA 90001    04
# ...                ...                                      ...   ...
# 186845  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001    09
# 186846  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016    09
# 186847  09/23/19 07:39     220 12th St, San Francisco, CA 94016    09
# 186848  09/19/19 17:30   511 Forest St, San Francisco, CA 94016    09
# 186849  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016    09
#
#         Sale_value            City State Zip Code
# 0        23.900000          Dallas    TX    75001
# 2        99.989998          Boston    MA    02215
# 3       600.000000     Los Angeles    CA    90001
# 4        11.990000     Los Angeles    CA    90001
# 5        11.990000     Los Angeles    CA    90001
# ...            ...             ...   ...      ...
# 186845    8.970000     Los Angeles    CA    90001
# 186846  700.000000   San Francisco    CA    94016
# 186847  700.000000   San Francisco    CA    94016
# 186848  379.989990   San Francisco    CA    94016
# 186849   11.950000   San Francisco    CA    94016
#
# [185950 rows x 11 columns]

# %%
res2= df.groupby('State').sum()['Sale_value']
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7880\2501806562.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   res2= df.groupby('State').sum()['Sale_value']

# %%
states= [state for state, df2 in df.groupby('State')]
#states= df['State'].unique()

plt.bar(states,res2)
# Out:
# <BarContainer object of 8 artists>

# %% [markdown]
# # What time we should advertise to maximize the sales

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df['Hour']= df['Order Date'].dt.hour

# %%
df['Minute'] = df['Order Date'].dt.minute

# %%
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable               2.0   11.950000
# 2        176559  Bose SoundSport Headphones               1.0   99.989998
# 3        176560                Google Phone               1.0  600.000000
# 4        176560            Wired Headphones               1.0   11.990000
# 5        176561            Wired Headphones               1.0   11.990000
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)               3.0    2.990000
# 186846   259354                      iPhone               1.0  700.000000
# 186847   259355                      iPhone               1.0  700.000000
# 186848   259356      34in Ultrawide Monitor               1.0  379.989990
# 186849   259357        USB-C Charging Cable               1.0   11.950000
#
#                 Order Date                         Purchase Address Month  \
# 0      2019-04-19 08:46:00             917 1st St, Dallas, TX 75001    04
# 2      2019-04-07 22:30:00        682 Chestnut St, Boston, MA 02215    04
# 3      2019-04-12 14:38:00     669 Spruce St, Los Angeles, CA 90001    04
# 4      2019-04-12 14:38:00     669 Spruce St, Los Angeles, CA 90001    04
# 5      2019-04-30 09:27:00        333 8th St, Los Angeles, CA 90001    04
# ...                    ...                                      ...   ...
# 186845 2019-09-17 20:56:00   840 Highland St, Los Angeles, CA 90001    09
# 186846 2019-09-01 16:00:00  216 Dogwood St, San Francisco, CA 94016    09
# 186847 2019-09-23 07:39:00     220 12th St, San Francisco, CA 94016    09
# 186848 2019-09-19 17:30:00   511 Forest St, San Francisco, CA 94016    09
# 186849 2019-09-30 00:18:00   250 Meadow St, San Francisco, CA 94016    09
#
#         Sale_value            City State Zip Code  Hour  Minute
# 0        23.900000          Dallas    TX    75001     8      46
# 2        99.989998          Boston    MA    02215    22      30
# 3       600.000000     Los Angeles    CA    90001    14      38
# 4        11.990000     Los Angeles    CA    90001    14      38
# 5        11.990000     Los Angeles    CA    90001     9      27
# ...            ...             ...   ...      ...   ...     ...
# 186845    8.970000     Los Angeles    CA    90001    20      56
# 186846  700.000000   San Francisco    CA    94016    16       0
# 186847  700.000000   San Francisco    CA    94016     7      39
# 186848  379.989990   San Francisco    CA    94016    17      30
# 186849   11.950000   San Francisco    CA    94016     0      18
#
# [185950 rows x 13 columns]

# %%
hours = [hour for hour, df2 in df.groupby('Hour')]

# %%
plt.plot(hours, df.groupby('Hour').count())
plt.xticks(hours)
plt.grid()
plt.ylabel("No of Orders")
plt.xlabel('Hours')
plt.show()

# %%
df.groupby('Hour').count()
# Out:
#       Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# Hour
# 0         3910     3910              3910        3910        3910
# 1         2350     2350              2350        2350        2350
# 2         1243     1243              1243        1243        1243
# 3          831      831               831         831         831
# 4          854      854               854         854         854
# 5         1321     1321              1321        1321        1321
# 6         2482     2482              2482        2482        2482
# 7         4011     4011              4011        4011        4011
# 8         6256     6256              6256        6256        6256
# 9         8748     8748              8748        8748        8748
# 10       10944    10944             10944       10944       10944
# 11       12411    12411             12411       12411       12411
# 12       12587    12587             12587       12587       12587
# 13       12129    12129             12129       12129       12129
# 14       10984    10984             10984       10984       10984
# 15       10175    10175             10175       10175       10175
# 16       10384    10384             10384       10384       10384
# 17       10899    10899             10899       10899       10899
# 18       12280    12280             12280       12280       12280
# 19       12905    12905             12905       12905       12905
# 20       12228    12228             12228       12228       12228
# 21       10921    10921             10921       10921       10921
# 22        8822     8822              8822        8822        8822
# 23        6275     6275              6275        6275        6275
#
#       Purchase Address  Month  Sale_value   City  State  Zip Code  Minute
# Hour
# 0                 3910   3910        3910   3910   3910      3910    3910
# 1                 2350   2350        2350   2350   2350      2350    2350
# 2                 1243   1243        1243   1243   1243      1243    1243
# 3                  831    831         831    831    831       831     831
# 4                  854    854         854    854    854       854     854
# 5                 1321   1321        1321   1321   1321      1321    1321
# 6                 2482   2482        2482   2482   2482      2482    2482
# 7                 4011   4011        4011   4011   4011      4011    4011
# 8                 6256   6256        6256   6256   6256      6256    6256
# 9                 8748   8748        8748   8748   8748      8748    8748
# 10               10944  10944       10944  10944  10944     10944   10944
# 11               12411  12411       12411  12411  12411     12411   12411
# 12               12587  12587       12587  12587  12587     12587   12587
# 13               12129  12129       12129  12129  12129     12129   12129
# 14               10984  10984       10984  10984  10984     10984   10984
# 15               10175  10175       10175  10175  10175     10175   10175
# 16               10384  10384       10384  10384  10384     10384   10384
# 17               10899  10899       10899  10899  10899     10899   10899
# 18               12280  12280       12280  12280  12280     12280   12280
# 19               12905  12905       12905  12905  12905     12905   12905
# 20               12228  12228       12228  12228  12228     12228   12228
# 21               10921  10921       10921  10921  10921     10921   10921
# 22                8822   8822        8822   8822   8822      8822    8822
# 23                6275   6275        6275   6275   6275      6275    6275
