# %% [markdown]
# #### First Analysis

# %% [markdown]
# #### Practise the basics

# %%
import pandas as pd
import os
import glob

# %%
pwd
# Out:
# 'D:\\Study\\pandas_practise\\SalesAnalysis'

# %%
df= pd.read_csv("./Sales_Data/Sales_July_2019.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14371 entries, 0 to 14370
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          14326 non-null  object
#  1   Product           14326 non-null  object
#  2   Quantity Ordered  14326 non-null  object
#  3   Price Each        14326 non-null  object
#  4   Order Date        14326 non-null  object
#  5   Purchase Address  14326 non-null  object
# dtypes: object(6)
# memory usage: 673.8+ KB

# %%
df.shape
# Out:
# (14371, 6)

# %%
df
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       222910  Apple Airpods Headphones                1        150
# 1       222911             Flatscreen TV                1        300
# 2       222912     AA Batteries (4-pack)                1       3.84
# 3       222913     AA Batteries (4-pack)                1       3.84
# 4       222914    AAA Batteries (4-pack)                5       2.99
# ...        ...                       ...              ...        ...
# 14366   236665          Wired Headphones                1      11.99
# 14367   236666              20in Monitor                1     109.99
# 14368   236667    AAA Batteries (4-pack)                1       2.99
# 14369   236668          Wired Headphones                1      11.99
# 14370   236669    AAA Batteries (4-pack)                1       2.99
#
#            Order Date                      Purchase Address
# 0      07/26/19 16:51       389 South St, Atlanta, GA 30301
# ...

# %%
type(df[['Product','Order ID']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   222910  Apple Airpods Headphones                1        150
# 1   222911             Flatscreen TV                1        300
# 2   222912     AA Batteries (4-pack)                1       3.84
# 3   222913     AA Batteries (4-pack)                1       3.84
# 4   222914    AAA Batteries (4-pack)                5       2.99
#
#        Order Date                  Purchase Address
# 0  07/26/19 16:51   389 South St, Atlanta, GA 30301
# 1  07/05/19 08:55     590 4th St, Seattle, WA 98101
# 2  07/29/19 12:41    861 Hill St, Atlanta, GA 30301
# 3  07/28/19 10:15   190 Ridge St, Atlanta, GA 30301
# 4  07/31/19 02:13  824 Forest St, Seattle, WA 98101

# %%
df.head(2)
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   222910  Apple Airpods Headphones                1        150
# 1   222911             Flatscreen TV                1        300
#
#        Order Date                 Purchase Address
# 0  07/26/19 16:51  389 South St, Atlanta, GA 30301
# 1  07/05/19 08:55    590 4th St, Seattle, WA 98101

# %%
df.tail()
# Out:
#       Order ID                 Product Quantity Ordered Price Each  \
# 14366   236665        Wired Headphones                1      11.99
# 14367   236666            20in Monitor                1     109.99
# 14368   236667  AAA Batteries (4-pack)                1       2.99
# 14369   236668        Wired Headphones                1      11.99
# 14370   236669  AAA Batteries (4-pack)                1       2.99
#
#            Order Date                      Purchase Address
# 14366  07/20/19 16:16      694 Meadow St, Atlanta, GA 30301
# 14367  07/31/19 20:11  866 14th St, San Francisco, CA 94016
# 14368  07/17/19 22:29       249 Cherry St, Dallas, TX 75001
# 14369  07/30/19 19:28       727 Wilson St, Austin, TX 73301
# 14370  07/10/19 01:50   743 9th St, New York City, NY 10001

# %%
df.tail(3)
# Out:
#       Order ID                 Product Quantity Ordered Price Each  \
# 14368   236667  AAA Batteries (4-pack)                1       2.99
# 14369   236668        Wired Headphones                1      11.99
# 14370   236669  AAA Batteries (4-pack)                1       2.99
#
#            Order Date                     Purchase Address
# 14368  07/17/19 22:29      249 Cherry St, Dallas, TX 75001
# 14369  07/30/19 19:28      727 Wilson St, Austin, TX 73301
# 14370  07/10/19 01:50  743 9th St, New York City, NY 10001

# %%
df[['Order ID','Product']]
# Out:
#       Order ID                   Product
# 0       222910  Apple Airpods Headphones
# 1       222911             Flatscreen TV
# 2       222912     AA Batteries (4-pack)
# 3       222913     AA Batteries (4-pack)
# 4       222914    AAA Batteries (4-pack)
# ...        ...                       ...
# 14366   236665          Wired Headphones
# 14367   236666              20in Monitor
# 14368   236667    AAA Batteries (4-pack)
# 14369   236668          Wired Headphones
# 14370   236669    AAA Batteries (4-pack)
#
# [14371 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')

# %%
df.iloc[0]
# Out:
# Order ID                                     222910
# Product                    Apple Airpods Headphones
# Quantity Ordered                                  1
# Price Each                                      150
# Order Date                           07/26/19 16:51
# Purchase Address    389 South St, Atlanta, GA 30301
# Name: 0, dtype: object

# %%
df.iloc[[0,1]]
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   222910  Apple Airpods Headphones                1        150
# 1   222911             Flatscreen TV                1        300
#
#        Order Date                 Purchase Address
# 0  07/26/19 16:51  389 South St, Atlanta, GA 30301
# 1  07/05/19 08:55    590 4th St, Seattle, WA 98101

# %%
df.iloc[[0,1],[1]]
# Out:
#                     Product
# 0  Apple Airpods Headphones
# 1             Flatscreen TV

# %%
df.iloc[[0,1],[1,0]]
# Out:
#                     Product Order ID
# 0  Apple Airpods Headphones   222910
# 1             Flatscreen TV   222911

# %%
df.loc[[0,1],["Product"]]
# Out:
#                     Product
# 0  Apple Airpods Headphones
# 1             Flatscreen TV

# %%
df.loc[[0,1],["Order ID"]]
# Out:
#   Order ID
# 0   222910
# 1   222911

# %%
df.loc[[],["Product"]]
# Out:
# Empty DataFrame
# Columns: [Product]
# Index: []

# %%
df.loc[2]
# Out:
# Order ID                                    222912
# Product                      AA Batteries (4-pack)
# Quantity Ordered                                 1
# Price Each                                    3.84
# Order Date                          07/29/19 12:41
# Purchase Address    861 Hill St, Atlanta, GA 30301
# Name: 2, dtype: object

# %%
df.set_index('Order ID')
# Out:
#                            Product Quantity Ordered Price Each  \
# Order ID
# 222910    Apple Airpods Headphones                1        150
# 222911               Flatscreen TV                1        300
# 222912       AA Batteries (4-pack)                1       3.84
# 222913       AA Batteries (4-pack)                1       3.84
# 222914      AAA Batteries (4-pack)                5       2.99
# ...                            ...              ...        ...
# 236665            Wired Headphones                1      11.99
# 236666                20in Monitor                1     109.99
# 236667      AAA Batteries (4-pack)                1       2.99
# 236668            Wired Headphones                1      11.99
# 236669      AAA Batteries (4-pack)                1       2.99
#
#               Order Date                      Purchase Address
# Order ID
# 222910    07/26/19 16:51       389 South St, Atlanta, GA 30301
# ...

# %%
df
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       222910  Apple Airpods Headphones                1        150
# 1       222911             Flatscreen TV                1        300
# 2       222912     AA Batteries (4-pack)                1       3.84
# 3       222913     AA Batteries (4-pack)                1       3.84
# 4       222914    AAA Batteries (4-pack)                5       2.99
# ...        ...                       ...              ...        ...
# 14366   236665          Wired Headphones                1      11.99
# 14367   236666              20in Monitor                1     109.99
# 14368   236667    AAA Batteries (4-pack)                1       2.99
# 14369   236668          Wired Headphones                1      11.99
# 14370   236669    AAA Batteries (4-pack)                1       2.99
#
#            Order Date                      Purchase Address
# 0      07/26/19 16:51       389 South St, Atlanta, GA 30301
# ...

# %%
df.set_index('Order ID', inplace=True)

# %%
df
# Out:
#                            Product Quantity Ordered Price Each  \
# Order ID
# 222910    Apple Airpods Headphones                1        150
# 222911               Flatscreen TV                1        300
# 222912       AA Batteries (4-pack)                1       3.84
# 222913       AA Batteries (4-pack)                1       3.84
# 222914      AAA Batteries (4-pack)                5       2.99
# ...                            ...              ...        ...
# 236665            Wired Headphones                1      11.99
# 236666                20in Monitor                1     109.99
# 236667      AAA Batteries (4-pack)                1       2.99
# 236668            Wired Headphones                1      11.99
# 236669      AAA Batteries (4-pack)                1       2.99
#
#               Order Date                      Purchase Address
# Order ID
# 222910    07/26/19 16:51       389 South St, Atlanta, GA 30301
# ...

# %%
df['Purchase Address'].str.len()
# Out:
# Order ID
# 222910    31.0
# 222911    29.0
# 222912    30.0
# 222913    31.0
# 222914    32.0
#           ...
# 236665    32.0
# 236666    36.0
# 236667    31.0
# 236668    31.0
# 236669    35.0
# Name: Purchase Address, Length: 14371, dtype: float64

# %%
df['Purchase Address'].str.contains("Seattle")
# Out:
# Order ID
# 222910    False
# 222911     True
# 222912    False
# 222913    False
# 222914     True
#           ...
# 236665    False
# 236666    False
# 236667    False
# 236668    False
# 236669    False
# Name: Purchase Address, Length: 14371, dtype: object

# %%
df.loc['222914']
# Out:
# Product                       AAA Batteries (4-pack)
# Quantity Ordered                                   5
# Price Each                                      2.99
# Order Date                            07/31/19 02:13
# Purchase Address    824 Forest St, Seattle, WA 98101
# Name: 222914, dtype: object

# %%
filt =  (df['Order Date'].str[0] == '0' )

# %%
df[filt]
# Out:
#                            Product Quantity Ordered Price Each  \
# Order ID
# 222910    Apple Airpods Headphones                1        150
# 222911               Flatscreen TV                1        300
# 222912       AA Batteries (4-pack)                1       3.84
# 222913       AA Batteries (4-pack)                1       3.84
# 222914      AAA Batteries (4-pack)                5       2.99
# ...                            ...              ...        ...
# 236665            Wired Headphones                1      11.99
# 236666                20in Monitor                1     109.99
# 236667      AAA Batteries (4-pack)                1       2.99
# 236668            Wired Headphones                1      11.99
# 236669      AAA Batteries (4-pack)                1       2.99
#
#               Order Date                      Purchase Address
# Order ID
# 222910    07/26/19 16:51       389 South St, Atlanta, GA 30301
# ...

# %%
fil = (df['Product'] == "AAA Batteries (4-pack)") | (df['Product'] == "AA Batteries (4-pack)")

# %%
df.loc[~fil,['Quantity Ordered','Order Date']]
# Out:
#          Quantity Ordered      Order Date
# Order ID
# 222910                  1  07/26/19 16:51
# 222911                  1  07/05/19 08:55
# 222915                  1  07/03/19 18:30
# 222916                  1  07/21/19 22:39
# 222917                  1  07/17/19 13:44
# ...                   ...             ...
# 236662                  1  07/09/19 14:41
# 236663                  1  07/17/19 07:26
# 236665                  1  07/20/19 16:16
# 236666                  1  07/31/19 20:11
# 236668                  1  07/30/19 19:28
#
# [11256 rows x 2 columns]

# %%
df.loc[fil,['Quantity Ordered','Order Date']]
# Out:
#          Quantity Ordered      Order Date
# Order ID
# 222912                  1  07/29/19 12:41
# 222913                  1  07/28/19 10:15
# 222914                  5  07/31/19 02:13
# 222920                  1  07/30/19 04:42
# 222923                  1  07/05/19 12:16
# ...                   ...             ...
# 236648                  2  07/04/19 18:28
# 236660                  1  07/23/19 12:38
# 236664                  1  07/03/19 08:18
# 236667                  1  07/17/19 22:29
# 236669                  1  07/10/19 01:50
#
# [3115 rows x 2 columns]

# %%
 df.loc[fil,['Quantity Ordered','Order Date']].head()
# Out:
#          Quantity Ordered      Order Date
# Order ID
# 222912                  1  07/29/19 12:41
# 222913                  1  07/28/19 10:15
# 222914                  5  07/31/19 02:13
# 222920                  1  07/30/19 04:42
# 222923                  1  07/05/19 12:16

# %%
fi = df['Purchase Address'].str.contains("Austin",na=True)

# %%
df['Purchase Address'].str.contains('NaN')
# Out:
# Order ID
# 222910    False
# 222911    False
# 222912    False
# 222913    False
# 222914    False
#           ...
# 236665    False
# 236666    False
# 236667    False
# 236668    False
# 236669    False
# Name: Purchase Address, Length: 14371, dtype: object

# %%
df.loc[fi]
# Out:
#                              Product Quantity Ordered Price Each  \
# Order ID
# 222971      Apple Airpods Headphones                1        150
# 222981          USB-C Charging Cable                1      11.95
# 222984          USB-C Charging Cable                1      11.95
# 223005              27in FHD Monitor                1     149.99
# 223012    Bose SoundSport Headphones                1      99.99
# ...                              ...              ...        ...
# 236609      Lightning Charging Cable                2      14.95
# NaN                              NaN              NaN        NaN
# 236653          USB-C Charging Cable                1      11.95
# 236656          USB-C Charging Cable                2      11.95
# 236668              Wired Headphones                1      11.99
#
#               Order Date                     Purchase Address
# Order ID
# 222971    07/05/19 14:49      444 Spruce St, Austin, TX 73301
# ...

# %%
df
# Out:
#                            Product Quantity Ordered Price Each  \
# Order ID
# 222910    Apple Airpods Headphones                1        150
# 222911               Flatscreen TV                1        300
# 222912       AA Batteries (4-pack)                1       3.84
# 222913       AA Batteries (4-pack)                1       3.84
# 222914      AAA Batteries (4-pack)                5       2.99
# ...                            ...              ...        ...
# 236665            Wired Headphones                1      11.99
# 236666                20in Monitor                1     109.99
# 236667      AAA Batteries (4-pack)                1       2.99
# 236668            Wired Headphones                1      11.99
# 236669      AAA Batteries (4-pack)                1       2.99
#
#               Order Date                      Purchase Address
# Order ID
# 222910    07/26/19 16:51       389 South St, Atlanta, GA 30301
# ...

# %%
type('Product')
# Out:
# str

# %%
fi
# Out:
# Order ID
# 222910    False
# 222911    False
# 222912    False
# 222913    False
# 222914    False
#           ...
# 236665    False
# 236666    False
# 236667    False
# 236668     True
# 236669    False
# Name: Purchase Address, Length: 14371, dtype: bool

# %%
df.columns
# Out:
# Index(['Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')

# %%
df.columns = [x.upper() for x in df.columns]
df
# Out:
#                            PRODUCT QUANTITY ORDERED PRICE EACH  \
# Order ID
# 222910    Apple Airpods Headphones                1        150
# 222911               Flatscreen TV                1        300
# 222912       AA Batteries (4-pack)                1       3.84
# 222913       AA Batteries (4-pack)                1       3.84
# 222914      AAA Batteries (4-pack)                5       2.99
# ...                            ...              ...        ...
# 236665            Wired Headphones                1      11.99
# 236666                20in Monitor                1     109.99
# 236667      AAA Batteries (4-pack)                1       2.99
# 236668            Wired Headphones                1      11.99
# 236669      AAA Batteries (4-pack)                1       2.99
#
#               ORDER DATE                      PURCHASE ADDRESS
# Order ID
# 222910    07/26/19 16:51       389 South St, Atlanta, GA 30301
# ...

# %%
df.columns = [x.lower() for x in df.columns]
df
# Out:
#                            product quantity ordered price each  \
# Order ID
# 222910    Apple Airpods Headphones                1        150
# 222911               Flatscreen TV                1        300
# 222912       AA Batteries (4-pack)                1       3.84
# 222913       AA Batteries (4-pack)                1       3.84
# 222914      AAA Batteries (4-pack)                5       2.99
# ...                            ...              ...        ...
# 236665            Wired Headphones                1      11.99
# 236666                20in Monitor                1     109.99
# 236667      AAA Batteries (4-pack)                1       2.99
# 236668            Wired Headphones                1      11.99
# 236669      AAA Batteries (4-pack)                1       2.99
#
#               order date                      purchase address
# Order ID
# 222910    07/26/19 16:51       389 South St, Atlanta, GA 30301
# ...

# %%
df.columns = df.columns.str.replace('product','Product')
df
# Out:
#                            Product quantity ordered price each  \
# Order ID
# 222910    Apple Airpods Headphones                1        150
# 222911               Flatscreen TV                1        300
# 222912       AA Batteries (4-pack)                1       3.84
# 222913       AA Batteries (4-pack)                1       3.84
# 222914      AAA Batteries (4-pack)                5       2.99
# ...                            ...              ...        ...
# 236665            Wired Headphones                1      11.99
# 236666                20in Monitor                1     109.99
# 236667      AAA Batteries (4-pack)                1       2.99
# 236668            Wired Headphones                1      11.99
# 236669      AAA Batteries (4-pack)                1       2.99
#
#               order date                      purchase address
# Order ID
# 222910    07/26/19 16:51       389 South St, Atlanta, GA 30301
# ...

# %%
df.rename(columns = {'quantity ordered':'Quantity Ordered', 'order date':'Order Date'}, inplace=True)

# %%
def Update_Quantity(Quantity_Ordered):
    return Quantity_Ordered

# %%
df['Quantity Ordered'].apply(Update_Quantity)
# Out:
# Order ID
# 222910    1
# 222911    1
# 222912    1
# 222913    1
# 222914    5
#          ..
# 236665    1
# 236666    1
# 236667    1
# 236668    1
# 236669    1
# Name: Quantity Ordered, Length: 14371, dtype: object

# %%
df
# Out:
#                            Product Quantity Ordered price each  \
# Order ID
# 222910    Apple Airpods Headphones                1        150
# 222911               Flatscreen TV                1        300
# 222912       AA Batteries (4-pack)                1       3.84
# 222913       AA Batteries (4-pack)                1       3.84
# 222914      AAA Batteries (4-pack)                5       2.99
# ...                            ...              ...        ...
# 236665            Wired Headphones                1      11.99
# 236666                20in Monitor                1     109.99
# 236667      AAA Batteries (4-pack)                1       2.99
# 236668            Wired Headphones                1      11.99
# 236669      AAA Batteries (4-pack)                1       2.99
#
#               Order Date                      purchase address
# Order ID
# 222910    07/26/19 16:51       389 South St, Atlanta, GA 30301
# ...

# %%
df['Product Rating'] = df['Quantity Ordered']

# %%
dffolder
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 dffolder
#
# NameError: name 'dffolder' is not defined

# %%
folder_path= './Sales_Data/'
files= glob.glob(folder_path+'/*.csv')
for file in files:
    dftemp= pd.read_csv(file)
    df1=df1.append(dftemp,ignore_index=True)

# %%
type[df1['Price Each']]

# %%
type[df1['Quantity Ordered']]

# %%
df1['Quantity Ordered']= pd.to_numeric(df1['Quantity Ordered'])

# %%
df1.loc[1679]

# %%
df1.set_index('Order ID')

# %%
df1.dtypes

# %%
df.shape

# %%
df1.shape

# %%
df1.info()

# %%
df1['Quantity Ordered'] = pd.to_numeric(df1['Quantity Ordered'] )

# %%
df1.loc[1679]

# %% [markdown]
# # df1.loc[1678]

# %%
df1

# %%
df2= pd.read_csv('./Sales_Data/Sales_September_2019.csv')

# %%
df2

# %%
df2.loc[1679]

# %%
df2.loc[1679,['Order ID']]

# %%
df2.loc[1678,['Order ID']]

# %%
fil= (df1['Order ID'] == 'Order ID')
df1[fil].drop

# %%
df1[fil]

# %%
df1.set_index('Order ID')

# %%
df1[fil]

# %%
df3=df1[fil]
df3

# %%
df1.info()

# %%
df1['Quantity Ordered']= df1['Quantity Ordered'].astype('float32')

# %%
df1['Sale_price']=df1['Price Each'] *df1['Quantity Ordered']

# %%
df1.set_index('Order ID',inplace=True)

# %%
d=df1['Month'].str.contains('NAN', na=True)

# %%
df1=df1.dropna(how='all')
